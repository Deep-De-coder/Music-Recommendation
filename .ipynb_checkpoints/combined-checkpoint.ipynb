# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('MusicPlayer.db')

# %%
sql_query = pd.read_sql_query ('''
                               SELECT
                               *
                               FROM Interactions
                               ''', conn)

# %%
df = pd.DataFrame(sql_query, columns = ['id', 'user_id', 'song_id' , 'like' , 'listen_count'])

# %%
print (df)
# Out:
#         id  user_id  song_id  like  listen_count
# 0        1        1      159     1           791
# 1        2        1       95     1           260
# 2        3        1      124     1           973
# 3        4        1       97     1           341
# 4        5        1      173     1           897
# ...    ...      ...      ...   ...           ...
# 3115  3116      156      383     1           350
# 3116  3117      156       62     1           359
# 3117  3118      156      480     1           551
# 3118  3119      156      112     1           947
# 3119  3120      156      480     1           655
#
# [3120 rows x 5 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import time 
import joblib
import app
from app import Interactions, db
from sqlalchemy import create_engine
import model.Recommenders as Recommenders
import model.Evaluation as Evaluation
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.8)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
sql_query = pd.read_sql_query ('''
                               SELECT
                               *
                               FROM Songs
                               ''', conn)

# %%
song_df = pd.DataFrame(sql_query, columns = ['id', 'name', 'path' , 'artist' , 'genre' , 'cover_photo' , 'duration' , 'total_likes' , 'total_listen_count'])

# %%
print(song_df)
# Out:
#       id                                     name  \
# 0      1                      Bikhoti Ka Mela.mp3
# 1      2                      Chakdait Chhora.mp3
# 2      3                         Jawa Pardesh.mp3
# 3      4                     Kan Full Khilana.mp3
# 4      5                   Latuli Teri Mukhdi.mp3
# ..   ...                                      ...
# 557  558  Hum Jane Pahchane Hain Kanihya Tere.mp3
# 558  559   Rang De Chunirya Shyam Naam Ki (1).mp3
# 559  560       Rang De Chunirya Shyam Naam Ki.mp3
# 560  561        Shyam Dhani Ke Male Main Jana.mp3
# 561  562        Jai Shiv Shankar Jai Mahadeva.mp3
#
#                                                   path         artist  \
# 0          Dataset\garhwali\Anil - Bikhoti Ka Mela.mp3           Anil
# 1          Dataset\garhwali\Anil - Chakdait Chhora.mp3           Anil
# 2             Dataset\garhwali\Anil - Jawa Pardesh.mp3           Anil
# 3         Dataset\garhwali\Anil - Kan Full Khilana.mp3           Anil
# 4       Dataset\garhwali\Anil - Latuli Teri Mukhdi.mp3           Anil
# ..                                                 ...            ...
# 557  Dataset\bhajan\Pappu Sharma - Hum Jane Pahchan...   Pappu Sharma
# 558  Dataset\bhajan\Pappu Sharma - Rang De Chunirya...   Pappu Sharma
# 559  Dataset\bhajan\Pappu Sharma - Rang De Chunirya...   Pappu Sharma
# 560  Dataset\bhajan\Pappu Sharma - Shyam Dhani Ke M...   Pappu Sharma
# 561  Dataset\bhajan\Ravindra Jain - Jai Shiv Shanka...  Ravindra Jain
#
#         genre                   cover_photo duration  total_likes  \
# 0    garhwali  /static/images/garhwali.jpeg      7:6            6
# 1    garhwali  /static/images/garhwali.jpeg     5:39            5
# 2    garhwali  /static/images/garhwali.jpeg     6:19            7
# 3    garhwali  /static/images/garhwali.jpeg     9:44            9
# 4    garhwali  /static/images/garhwali.jpeg     7:56            5
# ..        ...                           ...      ...          ...
# 557    bhajan    /static/images/bhajan.jpeg     6:47           11
# 558    bhajan    /static/images/bhajan.jpeg     8:16           20
# 559    bhajan    /static/images/bhajan.jpeg     8:16           22
# 560    bhajan    /static/images/bhajan.jpeg     6:24           17
# 561    bhajan    /static/images/bhajan.jpeg    18:24           13
#
#      total_listen_count
# 0                   420
# 1                   426
# 2                   582
# 3                    27
# 4                   564
# ..                  ...
# 557                 232
# 558                 445
# 559                 989
# 560                 156
# 561                 983
#
# [562 rows x 9 columns]

# %%
song_df.head()
# Out:
#    id                    name                                            path  \
# 0   1     Bikhoti Ka Mela.mp3     Dataset\garhwali\Anil - Bikhoti Ka Mela.mp3
# 1   2     Chakdait Chhora.mp3     Dataset\garhwali\Anil - Chakdait Chhora.mp3
# 2   3        Jawa Pardesh.mp3        Dataset\garhwali\Anil - Jawa Pardesh.mp3
# 3   4    Kan Full Khilana.mp3    Dataset\garhwali\Anil - Kan Full Khilana.mp3
# 4   5  Latuli Teri Mukhdi.mp3  Dataset\garhwali\Anil - Latuli Teri Mukhdi.mp3
#
#   artist     genre                   cover_photo duration  total_likes  \
# 0   Anil  garhwali  /static/images/garhwali.jpeg      7:6            6
# 1   Anil  garhwali  /static/images/garhwali.jpeg     5:39            5
# 2   Anil  garhwali  /static/images/garhwali.jpeg     6:19            7
# 3   Anil  garhwali  /static/images/garhwali.jpeg     9:44            9
# 4   Anil  garhwali  /static/images/garhwali.jpeg     7:56            5
#
#    total_listen_count
# 0                 420
# 1                 426
# 2                 582
# 3                  27
# 4                 564

# %%
song_df.rename(columns = {'id':'song_id'}, inplace = True)
song_df.head()
# Out:
#    song_id                    name  \
# 0        1     Bikhoti Ka Mela.mp3
# 1        2     Chakdait Chhora.mp3
# 2        3        Jawa Pardesh.mp3
# 3        4    Kan Full Khilana.mp3
# 4        5  Latuli Teri Mukhdi.mp3
#
#                                              path artist     genre  \
# 0     Dataset\garhwali\Anil - Bikhoti Ka Mela.mp3   Anil  garhwali
# 1     Dataset\garhwali\Anil - Chakdait Chhora.mp3   Anil  garhwali
# 2        Dataset\garhwali\Anil - Jawa Pardesh.mp3   Anil  garhwali
# 3    Dataset\garhwali\Anil - Kan Full Khilana.mp3   Anil  garhwali
# 4  Dataset\garhwali\Anil - Latuli Teri Mukhdi.mp3   Anil  garhwali
#
#                     cover_photo duration  total_likes  total_listen_count
# 0  /static/images/garhwali.jpeg      7:6            6                 420
# 1  /static/images/garhwali.jpeg     5:39            5                 426
# 2  /static/images/garhwali.jpeg     6:19            7                 582
# 3  /static/images/garhwali.jpeg     9:44            9                  27
# 4  /static/images/garhwali.jpeg     7:56            5                 564

# %%
merged_song_df = pd.merge(df, song_df.drop_duplicates(['song_id']), on="song_id", how="left")

# %%
merged_song_df.head()
# Out:
#    id  user_id  song_id  like  listen_count                              name  \
# 0   1        1      159     1           791               Yun Sajaa Chand.mp3
# 1   2        1       95     1           260        Yeh Dil Pagal Dil Mera.mp3
# 2   3        1      124     1           973  Shayad Main Zindagi Ki Sahar.mp3
# 3   4        1       97     1           341               Haath Chute Bhi.mp3
# 4   5        1      173     1           897         Khubsurat Hai Aankhen.mp3
#
#                                                 path        artist   genre  \
# 0  Dataset\ghazal\Pankaj Udhas - Yun Sajaa Chand.mp3  Pankaj Udhas  ghazal
# 1  Dataset\ghazal\Ghulam Ali - Yeh Dil Pagal Dil ...    Ghulam Ali  ghazal
# 2  Dataset\ghazal\Jagjit Singh - Shayad Main Zind...  Jagjit Singh  ghazal
# 3        Dataset\ghazal\Gulzar - Haath Chute Bhi.mp3        Gulzar  ghazal
# 4  Dataset\ghazal\Talat Aziz - Khubsurat Hai Aank...    Talat Aziz  ghazal
#
#                   cover_photo duration  total_likes  total_listen_count
# 0  /static/images/ghazal.jpeg     4:53           12                  40
# 1  /static/images/ghazal.jpeg      8:6           11                 403
# 2  /static/images/ghazal.jpeg     6:23           13                 753
# 3  /static/images/ghazal.jpeg     5:27            2                 431
# 4  /static/images/ghazal.jpeg     6:39            4                 897

# %%
merged_song_df.sort_values(by='song_id')
# Out:
#         id  user_id  song_id  like  listen_count  \
# 741    742       38        1     1           600
# 3019  3020      151        1     1           420
# 1004  1005       51        1     1            93
# 1823  1824       92        1     1           715
# 839    840       42        1     1           441
# ...    ...      ...      ...   ...           ...
# 2723  2724      137      562     1            12
# 499    500       25      562     1            93
# 1770  1771       89      562     1           240
# 3007  3008      151      562     1           983
# 203    204       11      562     1           958
#
#                                    name  \
# 741                 Bikhoti Ka Mela.mp3
# 3019                Bikhoti Ka Mela.mp3
# 1004                Bikhoti Ka Mela.mp3
# 1823                Bikhoti Ka Mela.mp3
# 839                 Bikhoti Ka Mela.mp3
# ...                                 ...
# 2723  Jai Shiv Shankar Jai Mahadeva.mp3
# 499   Jai Shiv Shankar Jai Mahadeva.mp3
# 1770  Jai Shiv Shankar Jai Mahadeva.mp3
# 3007  Jai Shiv Shankar Jai Mahadeva.mp3
# 203   Jai Shiv Shankar Jai Mahadeva.mp3
#
#                                                    path         artist  \
# 741         Dataset\garhwali\Anil - Bikhoti Ka Mela.mp3           Anil
# 3019        Dataset\garhwali\Anil - Bikhoti Ka Mela.mp3           Anil
# 1004        Dataset\garhwali\Anil - Bikhoti Ka Mela.mp3           Anil
# 1823        Dataset\garhwali\Anil - Bikhoti Ka Mela.mp3           Anil
# 839         Dataset\garhwali\Anil - Bikhoti Ka Mela.mp3           Anil
# ...                                                 ...            ...
# 2723  Dataset\bhajan\Ravindra Jain - Jai Shiv Shanka...  Ravindra Jain
# 499   Dataset\bhajan\Ravindra Jain - Jai Shiv Shanka...  Ravindra Jain
# 1770  Dataset\bhajan\Ravindra Jain - Jai Shiv Shanka...  Ravindra Jain
# 3007  Dataset\bhajan\Ravindra Jain - Jai Shiv Shanka...  Ravindra Jain
# 203   Dataset\bhajan\Ravindra Jain - Jai Shiv Shanka...  Ravindra Jain
#
#          genre                   cover_photo duration  total_likes  \
# 741   garhwali  /static/images/garhwali.jpeg      7:6            6
# 3019  garhwali  /static/images/garhwali.jpeg      7:6            6
# 1004  garhwali  /static/images/garhwali.jpeg      7:6            6
# 1823  garhwali  /static/images/garhwali.jpeg      7:6            6
# 839   garhwali  /static/images/garhwali.jpeg      7:6            6
# ...        ...                           ...      ...          ...
# 2723    bhajan    /static/images/bhajan.jpeg    18:24           13
# 499     bhajan    /static/images/bhajan.jpeg    18:24           13
# 1770    bhajan    /static/images/bhajan.jpeg    18:24           13
# 3007    bhajan    /static/images/bhajan.jpeg    18:24           13
# 203     bhajan    /static/images/bhajan.jpeg    18:24           13
#
#       total_listen_count
# 741                  420
# 3019                 420
# 1004                 420
# 1823                 420
# 839                  420
# ...                  ...
# 2723                 983
# 499                  983
# 1770                 983
# 3007                 983
# 203                  983
#
# [3120 rows x 13 columns]

# %%
len(merged_song_df)
# Out:
# 3120

# %%
#Creating a subset of our dataset

# %%
ong_df =ong_df = merged_song_df.head(100)

# %%
print(ong_df)
# Out:
#      id  user_id  song_id  like  listen_count  \
# 0     1        1      159     1           791
# 1     2        1       95     1           260
# 2     3        1      124     1           973
# 3     4        1       97     1           341
# 4     5        1      173     1           897
# ..  ...      ...      ...   ...           ...
# 95   96        5       63     1           250
# 96   97        5      222     1           702
# 97   98        5      163     1           538
# 98   99        5       81     1           961
# 99  100        5      204     1           505
#
#                                 name  \
# 0                Yun Sajaa Chand.mp3
# 1         Yeh Dil Pagal Dil Mera.mp3
# 2   Shayad Main Zindagi Ki Sahar.mp3
# 3                Haath Chute Bhi.mp3
# 4          Khubsurat Hai Aankhen.mp3
# ..                               ...
# 95        Mor Moriki Maand Pelya.mp3
# 96      Moh Moh Ke Dhaage (Male).mp3
# 97                 Ae jane Wafaa.mp3
# 98                        Gajiya.mp3
# 99       Jiya Dhadak Dhadak Jaye.mp3
#
#                                                  path               artist  \
# 0   Dataset\ghazal\Pankaj Udhas - Yun Sajaa Chand.mp3         Pankaj Udhas
# 1   Dataset\ghazal\Ghulam Ali - Yeh Dil Pagal Dil ...           Ghulam Ali
# 2   Dataset\ghazal\Jagjit Singh - Shayad Main Zind...         Jagjit Singh
# 3         Dataset\ghazal\Gulzar - Haath Chute Bhi.mp3               Gulzar
# 4   Dataset\ghazal\Talat Aziz - Khubsurat Hai Aank...           Talat Aziz
# ..                                                ...                  ...
# 95  Dataset\garhwali\Narendra Singh Negi - Mor Mor...  Narendra Singh Negi
# 96  Dataset\sufi\Papon - Moh Moh Ke Dhaage (Male).mp3                Papon
# 97      Dataset\ghazal\Talat Aziz - Ae jane Wafaa.mp3           Talat Aziz
# 98     Dataset\garhwali\Preetam Bhartwan - Gajiya.mp3     Preetam Bhartwan
# 99  Dataset\sufi\Faisal Rafi - Jiya Dhadak Dhadak ...          Faisal Rafi
#
#        genre                   cover_photo duration  total_likes  \
# 0     ghazal    /static/images/ghazal.jpeg     4:53           12
# 1     ghazal    /static/images/ghazal.jpeg      8:6           11
# 2     ghazal    /static/images/ghazal.jpeg     6:23           13
# 3     ghazal    /static/images/ghazal.jpeg     5:27            2
# 4     ghazal    /static/images/ghazal.jpeg     6:39            4
# ..       ...                           ...      ...          ...
# 95  garhwali  /static/images/garhwali.jpeg     7:25            7
# 96      sufi      /static/images/sufi.jpeg     5:22           20
# 97    ghazal    /static/images/ghazal.jpeg     6:40            7
# 98  garhwali  /static/images/garhwali.jpeg     6:29            7
# 99      sufi      /static/images/sufi.jpeg     2:39            9
#
#     total_listen_count
# 0                   40
# 1                  403
# 2                  753
# 3                  431
# 4                  897
# ..                 ...
# 95                 497
# 96                 546
# 97                 812
# 98                 332
# 99                 152
#
# [100 rows x 13 columns]

# %%
song_grouped = merged_song_df.groupby([‘song’]).agg({‘listen_count’: ‘count’}).reset_index()
# Out:
#   File "<ipython-input-24-14c7224fddc3>", line 1
#     song_grouped = merged_song_df.groupby([‘song’]).agg({‘listen_count’: ‘count’}).reset_index()
#                                                 ^
# SyntaxError: invalid character in identifier

# %%
train_data, test_data = train_test_split(merged_song_df, test_size = 0.20, random_state=0)

# %%
print(train_data.head(5))
# Out:
#         id  user_id  song_id  like  listen_count  \
# 867    868       44      519     1           585
# 2838  2839      142      527     1           242
# 1756  1757       88      249     1           858
# 2842  2843      143      490     1           904
# 682    683       35       10     1           736
#
#                                   name  \
# 867        Kanha Teri Murli Ki (1).mp3
# 2838           Mera Aapki Kripa Se.mp3
# 1756  Shukran Allah (From Kurbaan).mp3
# 2842             Manela Batiya Mor.mp3
# 682              Bedu Pako Barmasa.mp3
#
#                                                    path  \
# 867   Dataset\bhajan\Anup Jalota - Kanha Teri Murli ...
# 2838  Dataset\bhajan\Bhaiya Krishan Das Ji - Mera Aa...
# 1756  Dataset\sufi\SalimSulaiman - Shukran Allah (Fr...
# 2842  Dataset\bhojpuri\Ravi Kunwar - Manela Batiya M...
# 682   Dataset\garhwali\Anil Bist - Bedu Pako Barmasa...
#
#                      artist     genre                   cover_photo duration  \
# 867             Anup Jalota    bhajan    /static/images/bhajan.jpeg     3:28
# 2838  Bhaiya Krishan Das Ji    bhajan    /static/images/bhajan.jpeg     8:55
# 1756          SalimSulaiman      sufi      /static/images/sufi.jpeg     4:50
# 2842            Ravi Kunwar  bhojpuri  /static/images/bhojpuri.jpeg     7:55
# 682               Anil Bist  garhwali  /static/images/garhwali.jpeg     7:12
#
#       total_likes  total_listen_count
# 867            19                 909
# 2838           21                 119
# 1756           10                 169
# 2842           12                 904
# 682             9                 293

# %%
pm = Recommenders.popularity_recommender_py()

# %%
pm.create(train_data, 'user_id', 'name')

# %%
user_id = 1

# %%
pm.recommend(user_id)
# Out:
#      user_id                                name  score  Rank
# 72         1         Bol Pinjare Ka Tota Ram.mp3     14   1.0
# 310        1             Mera Aapki Kripa Se.mp3     14   2.0
# 429        1                    Sancha Naam Tera     14   3.0
# 458        1                 Sriman Narayana.mp3     14   4.0
# 187        1           Hridaya Banalo Bhakto.mp3     13   5.0
# 245        1         Kanha Teri Murli Ki (1).mp3     13   6.0
# 401        1  Rang De Chunirya Shyam Naam Ki.mp3     13   7.0
# 84         1                   Chandi Jaisa Rang     12   8.0
# 341        1   Nawazish Karam Shukriya Meharbani     12   9.0
# 487        1                 Tere Sang Yaara.mp3     12  10.0

# %%
pm.recommend(9)
# Out:
#      user_id                                name  score  Rank
# 72         9         Bol Pinjare Ka Tota Ram.mp3     14   1.0
# 310        9             Mera Aapki Kripa Se.mp3     14   2.0
# 429        9                    Sancha Naam Tera     14   3.0
# 458        9                 Sriman Narayana.mp3     14   4.0
# 187        9           Hridaya Banalo Bhakto.mp3     13   5.0
# 245        9         Kanha Teri Murli Ki (1).mp3     13   6.0
# 401        9  Rang De Chunirya Shyam Naam Ki.mp3     13   7.0
# 84         9                   Chandi Jaisa Rang     12   8.0
# 341        9   Nawazish Karam Shukriya Meharbani     12   9.0
# 487        9                 Tere Sang Yaara.mp3     12  10.0

# %%
is_model = Recommenders.item_similarity_recommender_py()

# %%
is_model.create(train_data, 'user_id', 'name')

# %%
user_id=7

# %%
user_items = is_model.get_user_items(user_id)

# %%
for user_item in user_items:
    print(user_item)
# Out:
# Tikuli Satale Bani.mp3
# Saaiyaan.mp3
# Allahu Akbar.mp3
# Sanu Ek Pal Chain.mp3
# Tum Se Hi.mp3
# Khamoshi
# Jeena Jeena (From Badlapur).mp3
# Thand Mathu Chaumaas.mp3
# Lagake Facewash.mp3
# Tere Sang Yaara.mp3
# Aaja Re Moray Saiyaan
# Sarkela Seeena Se Odhaniya.mp3
# Bheegi Bheegi.mp3
# Daal De Kewadi Mein Killi.mp3
# Nai-Lagda-_From-Notebook_.mp3
# Outro.mp3
# Kal Ho Naa Ho.mp3

# %%
is_model.recommend(user_id)
# Out:
# No. of unique songs for the user: 17
# no. of unique songs in the training set: 545
# Non zero values in cooccurence_matrix :1320
#   user_id                                               song     score rank
# 0       7                                  Channa Mereya.mp3  0.063662    1
# 1       7  Tujhe Kitna Chahne Lage (From Kabir Singh) (1)...  0.046172    2
# 2       7                                   Piya Milenge.mp3  0.043570    3
# 3       7                            Kabhi Yun Bhi To Ho.mp3  0.042760    4
# 4       7             High Rated Gabru (From Nawabzaade).mp3  0.041807    5
# 5       7                       Photo (From Luka Chuppi).mp3  0.040945    6
# 6       7                                      Zehnaseeb.mp3  0.040175    7
# 7       7                    Mehrama (From Love Aaj Kal).mp3  0.039385    8
# 8       7                                      All Black.mp3  0.039379    9
# 9       7                      Bhtar Jab Chhatiya Dabawe.mp3  0.038725   10

# %%
is_model.get_similar_items(['Saiyaan'])
# Out:
# no. of unique songs in the training set: 545
# Non zero values in cooccurence_matrix :0
#   user_id                                     song  score rank
# 0                            Suraj Ki Har Kiran Pe    0.0    1
# 1                              Chakdait Chhora.mp3    0.0    2
# 2                     Roots (feat Raja Kumari).mp3    0.0    3
# 3                          Nat Roop Ch Na Rang.mp3    0.0    4
# 4                         Maugi Ke Bada Nakhra.mp3    0.0    5
# 5                              Haath Chute Bhi.mp3    0.0    6
# 6                             Sajaye Payi Hain.mp3    0.0    7
# 7          Sabko Maloom Hai Main Sharabi Nahin.mp3    0.0    8
# 8                      Khuda Kare Ki Mohbbaat Main    0.0    9
# 9                 Mere Gully Mein (feat Naezy).mp3    0.0   10

# %%
is_model.get_similar_items(['Kun Faya Kun'])
# Out:
# no. of unique songs in the training set: 545
# Non zero values in cooccurence_matrix :0
#   user_id                                     song  score rank
# 0                            Suraj Ki Har Kiran Pe    0.0    1
# 1                              Chakdait Chhora.mp3    0.0    2
# 2                     Roots (feat Raja Kumari).mp3    0.0    3
# 3                          Nat Roop Ch Na Rang.mp3    0.0    4
# 4                         Maugi Ke Bada Nakhra.mp3    0.0    5
# 5                              Haath Chute Bhi.mp3    0.0    6
# 6                             Sajaye Payi Hain.mp3    0.0    7
# 7          Sabko Maloom Hai Main Sharabi Nahin.mp3    0.0    8
# 8                      Khuda Kare Ki Mohbbaat Main    0.0    9
# 9                 Mere Gully Mein (feat Naezy).mp3    0.0   10

# %%
is_model.get_similar_items(['Mere Gully Mein (feat Naezy).mp3'])
# Out:
# no. of unique songs in the training set: 545
# Non zero values in cooccurence_matrix :45
#   user_id                          song     score rank
# 0                      Banda Ban Ja.mp3  0.333333    1
# 1                 Sher Ka Bacha Jab.mp3  0.333333    2
# 2                 Bedu Pako Barmasa.mp3  0.333333    3
# 3               Nat Roop Ch Na Rang.mp3  0.250000    4
# 4                       Do Botalaan.mp3  0.250000    5
# 5          Hamar Saiya Aaj Ladan Se.mp3  0.250000    6
# 6             Khojyali Min Khojyali.mp3  0.250000    7
# 7                            Dawood.mp3  0.200000    8
# 8                          Kala Chashma  0.200000    9
# 9            Yeh Dil Pagal Dil Mera.mp3  0.200000   10

# %% [markdown]
# ## Quantitative comparison between the models¶
# We now formally compare the popularity and the personalized models using precision-recall curves.
#
# Class to calculate precision and recall (This can be used as a black box)

# %%
#Evaluation.precision_recall_calculator

# %%
# start = time.time()

# #Define what percentage of users to use for precision recall calculation
# user_sample = 0.05

# #Instantiate the precision_recall_calculator class
# pr = Evaluation.precision_recall_calculator(test_data, train_data, pm, is_model)

# #Call method to calculate precision and recall values
# (pm_avg_precision_list, pm_avg_recall_list, ism_avg_precision_list, ism_avg_recall_list) = pr.calculate_measures(user_sample)

# end = time.time()
# print(end - start)
